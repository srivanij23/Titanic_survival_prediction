# %% [markdown]
# # Titanic Survival Prediction
#
# This notebook demonstrates the Titanic survival prediction task using a decision tree classifier.
#
# We aim to predict whether a passenger survived the Titanic disaster based on features like age, gender, class, fare, etc.

# %% [markdown]
# import pandas as pd
#
# # Load Titanic dataset
# df = pd.read_csv('tested.csv')
# df.head()

# %%
titanic_test['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
#visualizing the survival distribution
plt.figure(figsize=(5,5))
titanic_test['Survived'].value_counts().plot(kind='bar',color=['r','g'])
plt.title('Survival Count')
plt.show()

# %%
titanic_test['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
#visiualizing the passenger class distribution
plt.figure(figsize=(5,5))
titanic_test['Pclass'].value_counts().plot(kind='bar',color=['orange','r','blue'])
plt.title('Passenger Class Disturbution')
plt.show()

# %%
#gender distribution 
plt.figure(figsize=(5, 5))
titanic_test['Sex'].value_counts().plot(
    kind='bar', 
    color=['yellow', 'pink']
)
plt.title('Gender Distribution')
plt.xticks(ticks=[0, 1], labels=['male', 'female'])
plt.ylabel('Count')
plt.xlabel('Gender')
plt.show()

# %%
#age distribution
plt.figure(figsize=(7,5))
plt.hist(titanic_test['Age'],bins=10,color='skyblue')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
from preprocess import preprocess_data

X, y = preprocess_data(titanic_test)

# %%
from train_model import train_and_evaluate_model

model, y_pred = train_and_evaluate_model(X, y)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
y.value_counts().plot(kind='bar', color=['salmon', 'lightgreen'])
plt.title("Survival Count")
plt.xticks([0, 1], ['Not Survived', 'Survived'], rotation=0)
plt.ylabel("Number of Passengers")
plt.show()

# %% [markdown]
# ## Conclusion
#
# The model shows strong performance in predicting Titanic passenger survival. Key influencing features include gender, passenger class, and fare. This project demonstrates a full ML pipeline with preprocessing, training, and evaluation.
